# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy as sp 
from sklearn.cluster import DBSCAN 
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import normalize 
from sklearn.decomposition import PCA

# %%
df1=pd.read_csv("01_District_wise_crimes_committed_IPC_2001_2012.csv")

# %%
df1.drop(["YEAR"], axis =1)
# Out:
#             STATE/UT       DISTRICT  MURDER  ATTEMPT TO MURDER  RAPE  \
# 0     ANDHRA PRADESH       ADILABAD     101                 60    50
# 1     ANDHRA PRADESH      ANANTAPUR     151                125    23
# 2     ANDHRA PRADESH       CHITTOOR     101                 57    27
# 3     ANDHRA PRADESH       CUDDAPAH      80                 53    20
# 4     ANDHRA PRADESH  EAST GODAVARI      82                 67    23
# ...              ...            ...     ...                ...   ...
# 9012     LAKSHADWEEP    LAKSHADWEEP       0                  0     0
# 9013     LAKSHADWEEP          TOTAL       0                  0     0
# 9014      PUDUCHERRY       KARAIKAL       5                  6     6
# 9015      PUDUCHERRY     PUDUCHERRY      24                 21     7
# 9016      PUDUCHERRY          TOTAL      29                 27    13
#
#       KIDNAPPING & ABDUCTION  DACOITY  PREPARATION AND ASSEMBLY FOR DACOITY  \
# ...

# %%
print(df1.columns)
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER', 'RAPE',
#        'KIDNAPPING & ABDUCTION', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'COUNTERFIETING',
#        'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %% [markdown]
# # scatter plot with legend

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='MURDER',y='ATTEMPT TO MURDER',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('MURDER vs ATTEMPT TO MURDER ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='INSULT TO MODESTY OF WOMEN',y='RAPE',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('INSULT TO MODESTY OF WOMEN vs RAPE')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='DOWRY DEATHS',y='CRUELTY BY HUSBAND OR HIS RELATIVES',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('DOWRY DEATHS vs CRUELTY BY HUSBAND OR HIS RELATIVES ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='DACOITY',y='PREPARATION AND ASSEMBLY FOR DACOITY',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('DACOITY vs PREPARATION AND ASSEMBLY FOR DACOITY ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='CRIMINAL BREACH OF TRUST',y='HURT/GREVIOUS HURT',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('CRIMINAL BREACH OF TRUST vs HURT/GREVIOUS HURT ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='ARSON',y='RIOTS',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title(' ARSON vs RIOTS')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='ROBBERY',y='BURGLARY',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('BURGLARY vs ROBBERY ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='CHEATING',y='COUNTERFIETING',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('CHEATING vs COUNTERFIETING ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='KIDNAPPING & ABDUCTION',y='THEFT',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('KIDNAPPING & ABDUCTION vs THEFT ')

plt.savefig('sc.png');

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(121)
sns.scatterplot(x='INSULT TO MODESTY OF WOMEN',y='ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',data=df1,palette='viridis',hue='STATE/UT',ax=ax)
ax.set_title('ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY vs INSULT TO MODESTY OF WOMEN')

plt.savefig('sc.png');

# %%
grp = df1.groupby('DISTRICT') 
a=grp.get_group('TOTAL')

# %%
a.shape
# Out:
# (408, 24)

# %%
data=df1.drop(df1[(df1['DISTRICT'] =="TOTAL" )].index)

# %% [markdown]
# # normal scatter plot

# %%
datas = data.drop(['STATE/UT', 'DISTRICT', 'YEAR' ], axis = 1)

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='MURDER',y='ATTEMPT TO MURDER',data=datas,aspect=2,height=6)
plt.xlabel('MURDER')
plt.ylabel('ATTEMPT TO MURDER')
plt.title('MURDER Vs ATTEMPT TO MURDER')
# Out:
# Text(0.5, 1.0, 'MURDER Vs ATTEMPT TO MURDER')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='DACOITY',y='PREPARATION AND ASSEMBLY FOR DACOITY',data=datas,aspect=2,height=6)
plt.xlabel('DACOITY')
plt.ylabel('PREPARATION AND ASSEMBLY FOR DACOITY')
plt.title('DACOITY Vs PREPARATION AND ASSEMBLY FOR DACOITY')
# Out:
# Text(0.5, 1.0, 'DACOITY Vs PREPARATION AND ASSEMBLY FOR DACOITY')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='CRUELTY BY HUSBAND OR HIS RELATIVES',y='DOWRY DEATHS',data=datas,aspect=2,height=6)
plt.xlabel('CRUELTY BY HUSBAND OR HIS RELATIVES')
plt.ylabel('DOWRY DEATHS')
plt.title('CRUELTY BY HUSBAND OR HIS RELATIVES Vs DOWRY DEATHS ')
# Out:
# Text(0.5, 1.0, 'CRUELTY BY HUSBAND OR HIS RELATIVES Vs DOWRY DEATHS ')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='RIOTS',y='ARSON',data=datas,aspect=2,height=6)
plt.xlabel('RIOTS')
plt.ylabel('ARSON')
plt.title(' RIOTS OR ARSON ')
# Out:
# Text(0.5, 1.0, ' RIOTS OR ARSON ')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='CHEATING',y='COUNTERFIETING',data=datas,aspect=2,height=6)
plt.xlabel('CHEATING')
plt.ylabel('COUNTERFIETING')
plt.title(' CHEATING OR COUNTERFIETING ')
# Out:
# Text(0.5, 1.0, ' CHEATING OR COUNTERFIETING ')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='CRIMINAL BREACH OF TRUST',y='HURT/GREVIOUS HURT',data=datas,aspect=2,height=6)
plt.xlabel('CRIMINAL BREACH OF TRUST')
plt.ylabel('HURT/GREVIOUS HURT')
plt.title('CRIMINAL BREACH OF TRUST OR HURT/GREVIOUS HURT')
# Out:
# Text(0.5, 1.0, 'CRIMINAL BREACH OF TRUST OR HURT/GREVIOUS HURT')

# %%
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')
sns.lmplot(x='RAPE',y='KIDNAPPING & ABDUCTION',data=datas,aspect=2,height=6)
plt.xlabel('RAPE')
plt.ylabel('KIDNAPPING & ABDUCTION')
plt.title('RAPE vs KIDNAPPING & ABDUCTION')
# Out:
# Text(0.5, 1.0, 'RAPE vs KIDNAPPING & ABDUCTION')

# %% [markdown]
# # population vs crime

# %%
dm=pd.read_csv("RR.csv")

# %%
dm.head()
# Out:
#             STATE/UT  TOTAL IPC CRIMES   polulation           zone
# 0      A & N ISLANDS              9102      417,036       Southern
# 1     ANDHRA PRADESH           2018981   49,576,777       Southern
# 2  ARUNACHAL PRADESH             27652    1,383,727  North-Eastern
# 3              ASSAM            597764   31,205,576  North-Eastern
# 4              BIHAR           1346293  104,099,452        Eastern

# %%
dm.rename({'polulation': 'population'}, axis=1, inplace=True)

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(121)
sns.scatterplot(x='population',y='TOTAL IPC CRIMES',data=dm,palette='viridis',hue='zone',ax=ax)
ax.set_title('TOTAL IPC CRIMES vs population')

plt.savefig('sc.png');
